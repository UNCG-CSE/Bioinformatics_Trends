# %%
#The cell below line[3] is the only alteration per each file extraction, changing only the filepath within quotations.

# %%
import json
import pandas
json_data = open(r'C:\Users\stevi\Downloads\School\CSC 505\scopus1986-2007.json').read()
data=json.loads(json_data)
#data[0]

# %%
#Check number of Elements in the 'data' list
len(data)
# Out:
# 18646

# %%
print(data[1845])

# %%
print(data[22]['abstracts-retrieval-response'])

# %%
for x in range(0,len(data)):
    if 'abstracts-retrieval-response' in data[x].keys():
        if 'affiliation' in data[x]['abstracts-retrieval-response'].keys():
            print (data[x]['abstracts-retrieval-response']['affiliation'])
        else:
            print ("not")

# %%
#Create dataframe
import pandas as pd
df= pd.DataFrame()

# %%
#Get all unique identifiers in a list (id)
id = []

for x in range(0,len(data)):
    if 'abstracts-retrieval-response' in data[x].keys():
        if 'affiliation'in data[x]['abstracts-retrieval-response']:
            if type(data[x]['abstracts-retrieval-response']['affiliation']) is list:
                id.append(data[x]['abstracts-retrieval-response']['affiliation'][0]['@id'])
                print(x)
            else:
                id.append(data[x]['abstracts-retrieval-response']['affiliation']['@id'])
        else:
            id.append("NaN")
    else:
        id.append("NaN")
        
len(id)

# %%
#Get all unique identifiers in a list (id)
id = []
name= []
country = []
#Get all eid (unique identifiers) of papers in a list
eid = []
#if statements checking conditions of list. Because some publications have lists, while others do not. 
for x in range(0,len(data)):
    if 'abstracts-retrieval-response' in data[x].keys():
        if 'affiliation'in data[x]['abstracts-retrieval-response']:
            if type(data[x]['abstracts-retrieval-response']['affiliation']) is list:
                for i in range(0, len(data[x]['abstracts-retrieval-response']['affiliation'])):
                     id.append(data[x]['abstracts-retrieval-response']['affiliation'][i]['@id'])
                     name.append(data[x]['abstracts-retrieval-response']['affiliation'][i]['affilname'])
                     country.append(data[x]['abstracts-retrieval-response']['affiliation'][i]['affiliation-country'])
                     eid.append(data[x]['abstracts-retrieval-response']['coredata']['eid'])
                     #print((data[x]['abstracts-retrieval-response']['affiliation'][i]['@id']))
            else:
                id.append(data[x]['abstracts-retrieval-response']['affiliation']['@id'])
                name.append(data[x]['abstracts-retrieval-response']['affiliation']['affilname'])
                country.append(data[x]['abstracts-retrieval-response']['affiliation']['affiliation-country'])
                eid.append(data[x]['abstracts-retrieval-response']['coredata']['eid'])
        else:
            id.append("NaN")
            name.append("NaN")
            country.append("NaN")
            eid.append(data[x]['abstracts-retrieval-response']['coredata']['eid'])
    else:
        id.append("NaN")
        name.append("NaN")
        country.append("NaN")
        eid.append("NaN") 
        
len(id)

# %%
len(eid)

# %%
[i for i, e in enumerate(eid) if e == 'NaN']

# %%
df['eid'] = eid
df["affiliation_id"] = id
df["affiliation_name"] = name
df["affiliation_country"] = country

# %%
df[:7]

# %%
# Cell below simliar to the top cell, whereas I change only the filename for the converted csv files relative to the years of csv file publications.

# %%
header = ["eid", "affiliation_id", "affiliation_name", "affiliation_country"]
df.to_csv('C:/Users/stevi/Downloads/School/CSC 505/affiliations_1986_2007.csv', columns = header, index = False)

# %%
#Reading CSV files
import pandas as pd

df = pd.read_csv(r'C:\Users\stevi\Downloads\School\CSC 505\affiliations_1986_2007.csv', dtype='str', sep=',', error_bad_lines=False)
df.shape
df.describe()

# %%
df['affiliation_country'].value_counts(dropna=True)

# %%
df['affiliation_name'].value_counts(dropna=True)

# %%
#Reading CSV files
import pandas as pd

df = pd.read_csv(r'C:\Users\stevi\Downloads\School\CSC 505\affiliations_2008_2009.csv', dtype='str', sep=',', error_bad_lines=False)
df.shape
df.describe()

# %%
df['affiliation_country'].value_counts(dropna=True)

# %%
df['affiliation_name'].value_counts(dropna=True)

# %%
#Reading CSV files
import pandas as pd

df = pd.read_csv(r'C:\Users\stevi\Downloads\School\CSC 505\affiliations_2010_2011.csv', dtype='str', sep=',', error_bad_lines=False)
df.shape
df.describe()

# %%
df['affiliation_country'].value_counts(dropna=True)

# %%
df['affiliation_name'].value_counts(dropna=True)

# %%
#Reading CSV files
import pandas as pd

df = pd.read_csv(r'C:\Users\stevi\Downloads\School\CSC 505\affiliations_2016_2017.csv', dtype='str', sep=',', error_bad_lines=False)
df.shape
df.describe()

# %%
df['affiliation_country'].value_counts(dropna=True)

# %%
df['affiliation_name'].value_counts(dropna=True)

# %%
df.head()

# %%
#Reading CSV files
import pandas as pd

df = pd.read_csv(r'C:\Users\stevi\Downloads\School\CSC 505\affiliations_2014_2015.csv', dtype='str', sep=',', error_bad_lines=False)
df.shape
df.describe()

# %%
df['affiliation_country'].value_counts(dropna=True)

# %%
df['affiliation_name'].value_counts(dropna=True)

# %%
#Reading CSV files
import pandas as pd

df = pd.read_csv(r'C:\Users\stevi\Downloads\School\CSC 505\affiliations_2012_2013.csv', dtype='str', sep=',', error_bad_lines=False)
df.shape
df.describe()

# %%
df['affiliation_country'].value_counts(dropna=True)

# %%
df['affiliation_name'].value_counts(dropna=True)

# %%
#df=df['affiliation_country'].value_counts(dropna=True)

# %%
#df=df['affiliation_country'].value_counts(dropna=True)

# %%
#Reading CSV files
import pandas as pd

df = pd.read_csv(r'C:\Users\stevi\Downloads\School\CSC 505\all_years_merged_steve_AffiliationData.csv',encoding='cp1252', dtype='str', sep=',', error_bad_lines=False)
df.shape
df.describe()
# Out:
#                        eid affiliation_id                   affiliation_name  \
# count               175052         170298                             170301
# unique               85082          24184                              22860
# top     2-s2.0-84957605211       60026124  European Bioinformatics Institute
# freq                   229            628                                629
#
#        affiliation_country
# count               169796
# unique                 167
# top          United States
# freq                 44775

# %%
#Getting the head of the data in csv file.
df.head()
# Out:
#                   eid affiliation_id  \
# 0  2-s2.0-38049161948       60092867
# 1  2-s2.0-38049161948       60013682
# 2  2-s2.0-36749042030       60026195
# 3  2-s2.0-84858487958       60005472
# 4  2-s2.0-84858487958       60027090
#
#                                     affiliation_name affiliation_country
# 0  Korea Institute of Science and Technology Info...         South Korea
# 1                          Seoul National University         South Korea
# 2        The Scottish Association for Marine Science      United Kingdom
# 3                            Bluefield State College       United States
# 4  Virginia Polytechnic Institute and State Unive...       United States

# %%
df['affiliation_name'].value_counts(dropna=True)
# Out:
# European Bioinformatics Institute                                            629
# Shanghai Jiaotong University                                                 575
# Chinese Academy of Sciences                                                  573
# University of California, San Diego                                          543
# Harvard Medical School                                                       472
# University of Cambridge                                                      470
# University of Manchester                                                     465
# Tongji University                                                            461
# University of Toronto                                                        444
# Zhejiang University                                                          435
# University of Washington, Seattle                                            435
# Fudan University                                                             431
# ...

# %%
df_temp1 = df['affiliation_name'].value_counts(dropna=True)

# %%
#Getting the tail
df.tail()
# Out:
#                        eid affiliation_id  \
# 175048  2-s2.0-84994403445       60085801
# 175049  2-s2.0-84994403445       60101854
# 175050  2-s2.0-84994403445       60016849
# 175051  2-s2.0-84994403445       60023022
# 175052  2-s2.0-84994403445       60006558
#
#                                  affiliation_name affiliation_country
# 175048            Li Ka Shing Knowledge Institute              Canada
# 175049      Ontario Institute for Cancer Research              Canada
# 175050                      University of Toronto              Canada
# 175051                   Toronto General Hospital              Canada
# 175052  McGill University Health Centre, Montreal              Canada

# %%
#defining my dataframe
df=df['affiliation_country'].value_counts(dropna=True)

# %%
df.tail()
# Out:
# Benin                 1
# Rwanda                1
# Dominican Republic    1
# Czechoslovakia        1
# Laos                  1
# Name: affiliation_country, dtype: int64

# %%
#needed to reset frames from above to retrieve expected results
df=df.reset_index()

# %%
#writing to new csv file
df.to_csv(r'C:\Users\stevi\Downloads\School\CSC 505\affiliations_all_years.csv', index=False)

# %%
#Reading CSV files
import pandas as pd

df1 = pd.read_csv(r'C:\Users\stevi\Downloads\School\CSC 505\all_years_merged_steve_AffiliationData.csv',encoding='cp1252', dtype='str', sep=',', error_bad_lines=False)
df1.shape
df1.describe()
# Out:
#                        eid affiliation_id                   affiliation_name  \
# count               175052         170298                             170301
# unique               85082          24184                              22860
# top     2-s2.0-84957605211       60026124  European Bioinformatics Institute
# freq                   229            628                                629
#
#        affiliation_country
# count               169796
# unique                 167
# top          United States
# freq                 44775

# %%
df1.dropna(inplace=True)
df1.shape
# Out:
# (169782, 4)

# %%
# Check data
df1.shape
# Out:
# (169782, 4)

# %%
#Reading CSV files
import pandas as pd
df2 = pd.read_csv(r'C:\Users\stevi\Downloads\School\CSC 505\all_years_merged(logan,mouna,darpan).csv',encoding='cp1252', dtype='str', sep=',', error_bad_lines=False)
df2.shape
df2.describe()
# Out:
#                        eid   cite   Lang  \
# count                85082  85082  77674
# unique               85082    604      3
# top     2-s2.0-77955813143      0    eng
# freq                     1  33192  77666
#
#                                                      Para  \
# count                                               77674
# unique                                              77466
# top     {'sup': ['1', '2', 'rd', '3', '4'], 'inf': ['1...
# freq                                                    7
#
#                                                     Title   year  \
# count                                               85082  85073
# unique                                              81311     29
# top     Lecture Notes in Computer Science (including s...   2015
# freq                                                 2532   8923
#
#                                          publication_name publication_type  \
# ...

# %%
#drop unneeded fields for specific look
df1.drop(['affiliation_id'], axis=1, inplace=True)
df1[:10]
# Out:
#                   eid                                   affiliation_name  \
# 0  2-s2.0-38049161948  Korea Institute of Science and Technology Info...
# 1  2-s2.0-38049161948                          Seoul National University
# 2  2-s2.0-36749042030        The Scottish Association for Marine Science
# 3  2-s2.0-84858487958                            Bluefield State College
# 4  2-s2.0-84858487958  Virginia Polytechnic Institute and State Unive...
# 5  2-s2.0-84858511527                       Fort Valley State University
# 6  2-s2.0-84858503835  Virginia Polytechnic Institute and State Unive...
# 7  2-s2.0-84858503835                            Bluefield State College
# 8  2-s2.0-37349108551               UNESP-Universidade Estadual Paulista
# 9  2-s2.0-37349108551                    Universidade de Sao Paulo - USP
#
#   affiliation_country
# 0         South Korea
# 1         South Korea
# 2      United Kingdom
# 3       United States
# 4       United States
# 5       United States
# ...

# %%
#drop fields not needed for my research
df2.drop(['Author Keyword','Lang', 'Para', 'Title', 'year', 'publication_name', 'publication_type', 'Abbreviation', 'Code', 'Text'], axis=1, inplace=True)
df2[:10]
# Out:
#                   eid cite
# 0  2-s2.0-38049161948    2
# 1  2-s2.0-36749042030   17
# 2  2-s2.0-84858487958    0
# 3  2-s2.0-84858511527    0
# 4  2-s2.0-84858503835    0
# 5  2-s2.0-37349108551    3
# 6  2-s2.0-37349041400    7
# 7  2-s2.0-37349014523    3
# 8  2-s2.0-84858512072    0
# 9  2-s2.0-37349065612    6

# %%
#merge data fields
df_merged = df1.merge(df2, how ='left', on = 'eid')
df_merged
# Out:
#                        eid                                   affiliation_name  \
# 0       2-s2.0-38049161948  Korea Institute of Science and Technology Info...
# 1       2-s2.0-38049161948                          Seoul National University
# 2       2-s2.0-36749042030        The Scottish Association for Marine Science
# 3       2-s2.0-84858487958                            Bluefield State College
# 4       2-s2.0-84858487958  Virginia Polytechnic Institute and State Unive...
# 5       2-s2.0-84858511527                       Fort Valley State University
# 6       2-s2.0-84858503835  Virginia Polytechnic Institute and State Unive...
# 7       2-s2.0-84858503835                            Bluefield State College
# 8       2-s2.0-37349108551               UNESP-Universidade Estadual Paulista
# 9       2-s2.0-37349108551                    Universidade de Sao Paulo - USP
# 10      2-s2.0-37349041400  Pontificia Universidade Catolica do Rio Grande...
# ...

# %%
#prepare comparisons for pdf functional graph
df_topACount = df_merged.loc[df_merged['affiliation_name'].isin(['European Bioinfomatics Institute'])]
df_topBCount = df_merged.loc[df_merged['affiliation_name'].isin(['Shanghai Jiaotong University'])]
df_topACite = df_merged.loc[df_merged['affiliation_name'].isin(['Bioinfomatics Group'])]
df_topBCite = df_merged.loc[df_merged['affiliation_name'].isin(['Cellzome AG'])]

# %%
##prepare comparisons of data for functional graph
df_topACount['cite'] = pd.to_numeric(df_topACount['cite'], downcast=None)
df_topBCount['cite'] = pd.to_numeric(df_topBCount['cite'], downcast=None)
df_topACite['cite'] = pd.to_numeric(df_topACite['cite'], downcast=None)
df_topBCite['cite'] = pd.to_numeric(df_topBCite['cite'], downcast=None)
# Out:
# C:\Users\stevi\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\stevi\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
#top University Publication count
df_topACount
# Out:
# Empty DataFrame
# Columns: [eid, affiliation_name, affiliation_country, cite]
# Index: []

# %%
#second highest
df_topBCount
# Out:
#                        eid              affiliation_name affiliation_country  \
# 182     2-s2.0-37148999906  Shanghai Jiaotong University               China
# 263     2-s2.0-44249109690  Shanghai Jiaotong University               China
# 486     2-s2.0-38349077092  Shanghai Jiaotong University               China
# 556     2-s2.0-38349032884  Shanghai Jiaotong University               China
# 1022    2-s2.0-78049350828  Shanghai Jiaotong University               China
# 1115    2-s2.0-47649098285  Shanghai Jiaotong University               China
# 1131    2-s2.0-47649107207  Shanghai Jiaotong University               China
# 1254    2-s2.0-84863142674  Shanghai Jiaotong University               China
# 1359    2-s2.0-47649121506  Shanghai Jiaotong University               China
# 1595    2-s2.0-38049171044  Shanghai Jiaotong University               China
# 2211    2-s2.0-38549118300  Shanghai Jiaotong University               China
# ...

# %%
#top highest avg citation count
df_topACite
# Out:
# Empty DataFrame
# Columns: [eid, affiliation_name, affiliation_country, cite]
# Index: []

# %%
#second highest avg citation count
df_topBCite
# Out:
#                        eid affiliation_name affiliation_country  cite
# 18249   2-s2.0-20544453451      Cellzome AG             Germany     2
# 22400   2-s2.0-13244289881      Cellzome AG             Germany   244
# 23179   2-s2.0-12144290243      Cellzome AG             Germany   271
# 25500    2-s2.0-0042622252      Cellzome AG             Germany   442
# 26521    2-s2.0-0037843702      Cellzome AG             Germany     0
# 37753   2-s2.0-71749106147      Cellzome AG             Germany    27
# 105570  2-s2.0-84865576726      Cellzome AG             Germany   272

# %%
#pdf graph
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

sns.distplot(df_topBCount['cite'], hist = False, kde = True,kde_kws = {'shade': True, 'linewidth': 3}, label = 'Shanghai Jiaotong U.')
sns.distplot(df_topBCite['cite'], hist = False, kde = True,kde_kws = {'shade': True, 'linewidth': 3}, label = 'Cellzome AG')
sns.set(font_scale = 1)
plt.xlim(0,750)
# Out:
# (0, 750)

# %%
del df_merged['eid']
df_merged['cite'] = pd.to_numeric(df_merged['cite'])
#df_merged = df_merged[df_merged['cite'] < 400]
df_merged.isnull().sum()
# Out:
# affiliation_name       0
# affiliation_country    0
# cite                   0
# dtype: int64

# %%
#sort merged datd
df_merged = df_merged.sort_values('cite', ascending=False)
df_merged
# Out:
#                                          affiliation_name affiliation_country  \
# 59440                            Arizona State University       United States
# 59438                       Tokyo Metropolitan University               Japan
# 59439                       Pennsylvania State University       United States
# 2794                    European Bioinformatics Institute      United Kingdom
# 2795                            University College Dublin             Ireland
# 2796     European Molecular Biology Laboratory Heidelberg             Germany
# 2797    IGBMC Institut de Genetique et de Biologie Mol...              France
# 42609                                      SAIC-Frederick       United States
# 39857                                      Boston College       United States
# 39856               University of California, Los Angeles       United States
# 39854      University of Michigan School of Public Health       United States
# ...

# %%
#using grouby to find mean average
df_merged = df_merged.groupby(['affiliation_name', 'affiliation_country']).mean()
df_merged
# Out:
#                                                                          cite
# affiliation_name                                   affiliation_country
# "A. Perrino" Hospital                              Italy                  3.0
# "Città della Salute e della Scienza" Hospital o... Italy                  4.0
# 'Istituto per l'Ambiente Marino Costiero del Co... Italy                 17.0
# 'Modeling in Integrative Biology' Group            France                20.0
# 'San Giuseppe Moscati' Hospital                    Italy                  6.0
# (Biomarker Research in Mass Spectrometry)          United States          3.0
# 100th Hospital of PLA                              China                  1.0
# 101 Institute of the Ministry of Civil Affairs     China                  1.0
# 1025 Crop Genome Informatics Laboratory            United States          0.0
# 105th Hospital of PLA                              China                  1.0
# ...

# %%
df_merged=df_merged.reset_index()

# %%
#df_merged.sort_values("cite", ascending = False, inplace = True)
df_merged
# Out:
#                                         affiliation_name affiliation_country  \
# 0                                  "A. Perrino" Hospital               Italy
# 1      "Città della Salute e della Scienza" Hospital ...               Italy
# 2      'Istituto per l'Ambiente Marino Costiero del C...               Italy
# 3                'Modeling in Integrative Biology' Group              France
# 4                        'San Giuseppe Moscati' Hospital               Italy
# 5              (Biomarker Research in Mass Spectrometry)       United States
# 6                                  100th Hospital of PLA               China
# 7         101 Institute of the Ministry of Civil Affairs               China
# 8                1025 Crop Genome Informatics Laboratory       United States
# 9                                  105th Hospital of PLA               China
# 10     107 Hospital of The Chinese People's Liberatio...               China
# ...

# %%
#sort cites
df_merged = df_merged.sort_values(by = 'cite', ascending = False)

# %%
#check data
df_merged
# Out:
#                                         affiliation_name affiliation_country  \
# 4147                                            ClopiNet       United States
# 19281                              Toxicology Department       United States
# 12482                                     Matrix Science      United Kingdom
# 19218                      Tokyo Metropolitan University               Japan
# 15208                            Perlegen Sciences, Inc.       United States
# 444                     Agencourt Bioscience Corporation       United States
# 15972                   Real World Computing Partnership               Japan
# 19739                     Unite de Recherche Rhone-Alpes              France
# 17642                 Simone Protective Cancer Institute       United States
# 4962                  Devmtl. Therapeutics Program (DTP)       United States
# 6542   Functional Genomics Node (National Institute f...               Spain
# ...

# %%
#etract top 10
df_merged.loc[df_merged['affiliation_name'].isin(['European Bioinformatics Institute','Shanghai Jiaotong University','Chinese Academy of Sciences','University of California, San Diego','Harvard Medical School','University of Cambridge','University of Manchester','Tongji University','University of Toronto','Zhejiang University','University of Washington, Seattle'])]
# Out:
#                           affiliation_name affiliation_country        cite
# 3912           Chinese Academy of Sciences               China   22.834206
# 5775     European Bioinformatics Institute      United Kingdom   99.106688
# 5776     European Bioinformatics Institute       United States  751.000000
# 7640                Harvard Medical School       United States   52.735169
# 17285         Shanghai Jiaotong University               China   12.453913
# 19249                    Tongji University               China    3.360870
# 19250                    Tongji University               India    0.000000
# 20780  University of California, San Diego       United States   40.279926
# 20786              University of Cambridge      United Kingdom   40.823404
# 21060             University of Manchester      United Kingdom   35.443011
# 21431                University of Toronto              Canada   37.900901
# ...

# %%
#df_topACount.describe()
df_merged
# Out:
#                                         affiliation_name affiliation_country  \
# 4147                                            ClopiNet       United States
# 19281                              Toxicology Department       United States
# 12482                                     Matrix Science      United Kingdom
# 19218                      Tokyo Metropolitan University               Japan
# 15208                            Perlegen Sciences, Inc.       United States
# 444                     Agencourt Bioscience Corporation       United States
# 15972                   Real World Computing Partnership               Japan
# 19739                     Unite de Recherche Rhone-Alpes              France
# 17642                 Simone Protective Cancer Institute       United States
# 4962                  Devmtl. Therapeutics Program (DTP)       United States
# 6542   Functional Genomics Node (National Institute f...               Spain
# ...

# %%
df1.loc[(df1['affiliation_name'].isin(['European Bioinformatics Institute'])) & df1['affiliation_country'].isin(['United States'])]
# Out:
#                       eid                   affiliation_name  \
# 85076  2-s2.0-77954296666  European Bioinformatics Institute
#
#       affiliation_country
# 85076       United States

# %%
#cheach data headers
list(df_merged)
# Out:
# ['affiliation_name', 'affiliation_country', 'cite']

# %%
#Get all eid (unique identifiers) of papers in a list
#eid = []
#
#for x in range(4145,len(data)):
#    print(x)
#    if 'abstracts-retrieval-response' in data[x].keys():
#        if 'dc:description' in data[x]['abstracts-retrieval-response']['coredata'].keys():
#            langList.append(data[x]['abstracts-retrieval-response']['coredata']['dc:description']['abstract'][0]['@xml:lang'])
#        else:
#            langList.append('NaN')
#    else:
#        print("2",x)

# %%
#Get all countries referenced in the papers in a list
#ctrylist = []
#
#for x in range(0,len(data)):
#   if 'abstracts-retrieval-response' in data[x].keys():
#        if 'affiliation' in data[x]['abstracts-retrieval-response'].keys():
#            ctrylist.append(data[x]['abstracts-retrieval-response']['affiliation'][0]['affiliation-country'])
#        else:
#            ctrylist.append("NaN")
#    else:
#        ctrylist.append("NaN")
#        
#len(ctrylist)

# %%
#len(ctrylist)

# %%
#print(data[7342]['abstracts-retrieval-response']['dc:description']['abstract'][1]['@xml:lang'])
