# %%
import matplotlib 
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import json
import pandas
import pandas as pd
import csv
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\Luke\Desktop\Fall_2018\505\project_csvs\authorData_10_11.csv', encoding='cp1252', dtype='str', error_bad_lines=False)
df.shape
# Out:
# (67142, 5)

# %%
del df['Unnamed: 0']

# %%
df.columns = ['eid', 'Author_ID', 'Author_Seq', 'Author_Name']

# %%
df.head()
# Out:
#                   eid    Author_ID Author_Seq         Author_Name
# 0  2-s2.0-84863501426  16416747200          1           Daam M.A.
# 1  2-s2.0-84863501426  56585600100          2  Van Den Brink P.J.
# 2  2-s2.0-84863031252  55268445600          1               Li P.
# 3  2-s2.0-84863031252  55268863300          2            Zhang J.
# 4  2-s2.0-84863031252  55781316200          3            Li A.-H.

# %%
eid_counts = df['eid'].value_counts()

# %%
eid_counts.head()
# Out:
# 2-s2.0-79958143783    143
# 2-s2.0-78651319979    126
# 2-s2.0-77955373370     82
# 2-s2.0-80054973816     70
# 2-s2.0-79953755048     69
# Name: eid, dtype: int64

# %%
eid_counts.hist()

# %%
pd.DataFrame(eid_counts).plot(kind="kde",  # Plot the distribution
                               figsize=(12,12),
                               xlim=(0,30),
                               ylim=(0,.2),
                               fontsize=15.0,
                               grid=True,
                               title="Probability Distribution for # of authors")

# %%
sns.kdeplot(np.array(eid_counts), bw=0.5)

# %%
df['eid'].value_counts().hist()

# %%
test = df
test = test.dropna()

# %%
test = df
test = test.dropna()
del test['Author_ID']
del test['Author_Name']

# %%
test.head()

# %%
test['Author_Seq'] = test['Author_Seq'].astype(str).astype(int)

# %%
test['Author_Seq'].index[2]

# %%
for x in range(1, len(test)):
    if int(test.loc[test['Author_Seq'].index[x],'Author_Seq']) > int(test.loc[test['Author_Seq'].index[x-1],'Author_Seq']):
        test = test.drop(test.index[x-1])
        x = x - 1

# %%
test['Author_Seq'].value_counts()

# %%
test['Author_Seq'].dtype

# %%
test = df

# %%
test = test.dropna()

# %%
test.Author_Seq.unique()

# %%
test = test.drop(test.index[0])

# %%
int(test.loc[0,'Author_Seq'])

# %%
test.head()

# %%
seq_counts = test['Author_Seq']
seq_counts.counts()

# %%
df.eid.dtype

# %%
test2.dtype

# %%
test = df['eid']
test = test.astype(str)
test2 = df['Author_Seq']
test2 = test2.astype(int)
eid_seq = pd.concat([test, test2], axis=1)

# %%
df.columns = ['Leader', 'Time', 'Score']

# %%
df2 = df['cite']
df2 = df2.astype(str).astype(int)
df2.values

# %%
print(type(df2))
print(df2.head())

# %%
df2.value_counts().max()

# %%
df2.value_counts().hist()

# %%
# this is excluding outlier at about 6500 citations
pd.DataFrame(df2.value_counts()).plot(kind="density",  # Plot the distribution
                               figsize=(12,12),
                               xlim=(0,1500),
                               ylim=(0,.0030))

# %%
sns.kdeplot(np.array(df2.value_counts()), bw=0.5)

# %%
plt.hist(df2.value_counts())
plt.title("Gaussian Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()
