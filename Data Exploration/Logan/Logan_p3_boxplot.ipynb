# %% [markdown]
# # Breakdown of avg citations per paper (grouped by field of study) for the following:
# - top 10 most published
# - top 10 most cited
# - top 2 most published
# - top 2 most cited
#
# Read merged (all years) CSV file into data frame:

# %%
import csv
import pandas as pd
from ast import literal_eval

df_logan = pd.read_csv(r'/Users/loganhornbuckle/Documents/Data_Science/Merged/all_years_merged_logan_mouna_darpan.csv',
                       encoding='cp1252' ,dtype='str', error_bad_lines=False)

# get dimmensions of dataframe to ensure csv imported correctly
df_logan.shape
# Out:
# (85082, 12)

# %%
df_logan['cite'] = pd.to_numeric(df_logan['cite'], downcast=None)

# %%
df_thCSC = df_logan.loc[df_logan['Text'].isin(['Theoretical Computer Science'])]
df_genCSC = df_logan.loc[df_logan['Text'].isin(['Computer Science (all)'])]
df_molBIO = df_logan.loc[df_logan['Text'].isin(['Molecular Biology'])]
df_GEN = df_logan.loc[df_logan['Text'].isin(['Genetics'])]
df_appCSC = df_logan.loc[df_logan['Text'].isin(['Computer Science Applications'])]
df_BIOcheMB = df_logan.loc[df_logan['Text'].isin(['Biochemistry, Genetics and Molecular Biology (all)'])]
df_BIOMedEng = df_logan.loc[df_logan['Text'].isin(['Biomedical Engineering'])]
df_BIOchem = df_logan.loc[df_logan['Text'].isin(['Biochemistry'])]
df_MED = df_logan.loc[df_logan['Text'].isin(['Medicine (all)'])]
df_MATH = df_logan.loc[df_logan['Text'].isin(['Applied Mathematics'])]
df_BIOtech = df_logan.loc[df_logan['Text'].isin(['Biotechnology'])]

# %% [markdown]
# # Compare distributions of Most cited/published subjects

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(rc={'figure.figsize':(25,20)})

sns.distplot(df_appCSC['cite'], hist = False, kde = True,kde_kws = {'shade': True, 'linewidth': 3}, label = 'App CSC')
sns.distplot(df_GEN['cite'], hist = False, kde = True,kde_kws = {'shade': True, 'linewidth': 3}, label = 'Genetics')
sns.distplot(df_BIOcheMB['cite'], hist = False, kde = True,kde_kws = {'shade': True, 'linewidth': 3}, label = 'BioChem')
sns.distplot(df_MATH['cite'], hist = False, kde = True,kde_kws = {'shade': True, 'linewidth': 3}, label = 'Math')
sns.distplot(df_molBIO['cite'], hist = False, kde = True,kde_kws = {'shade': True, 'linewidth': 3}, label = 'Mol Bio')

plt.xlim(0,200)
# Out:
# (0, 200)

# %% [markdown]
# # Compare prob dist of Mathematics & Biochem.
# - Both subjects in top of their groups (most cited & most published)
# - While BioChem appeared in both groups, Mathematics only appeared in one top 10 group. Hoping to possibly explain w/ this graph:

# %%
sns.distplot(df_MATH['cite'], hist = False, kde = True,kde_kws = {'shade': True, 'linewidth': 3}, label = 'Math')

sns.distplot(df_BIOchem['cite'], hist = False, kde = True,kde_kws = {'shade': True, 'linewidth': 3}, label = 'BioChem')

plt.xlim(0,200)
# Out:
# (0, 200)

# %%
# top 2 from pub & cite

 

sns.distplot(df_thCSC['cite'], hist = False, kde = True,kde_kws = {'shade': True, 'linewidth': 3}, label = 'Theoretical CSC')
sns.distplot(df_genCSC['cite'], hist = False, kde = True,kde_kws = {'shade': True, 'linewidth': 3}, label = 'General CSC')
sns.distplot(df_MATH['cite'], hist = False, kde = True,kde_kws = {'shade': True, 'linewidth': 3}, label = 'Math')
sns.distplot(df_molBIO['cite'], hist = False, kde = True,kde_kws = {'shade': True, 'linewidth': 3}, label = 'Molecular BIO')



plt.xlim(0,200)
# Out:
# (0, 200)

# %% [markdown]
# # frames = [df_molBIO, df_genCSC, df_thCSC, df_appCSC, df_GEN, df_BIOcheMB, df_BIOMedEng, df_BIOchem, df_MED, df_BIOtech]
#
# top10Pub = pd.concat(frames)

# %%
frames = [df_MATH, df_molBIO, df_genCSC, df_thCSC, df_appCSC, df_GEN, df_BIOcheMB, df_BIOMedEng, df_BIOchem, df_MED]

top10Cite = pd.concat(frames)

# %%
sns.boxplot(x='cite', y='Text',data=top10Pub)
sns.set(font_scale=3)
plt.xlim(0,35)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-1eac030fce4d> in <module>
# ----> 1 sns.boxplot(x='cite', y='Text',data=top10Pub)
#       2 sns.set(font_scale=3)
#       3 plt.xlim(0,35)
#       4 plt.show()
#
# NameError: name 'top10Pub' is not defined

# %%
sns.boxplot(x='cite', y='Text', data=top10Cite)
sns.set(font_scale=1.5)

plt.xlim(0,100)
plt.show()
