# %%
import csv
import pandas as pd
from ast import literal_eval

df_logan = pd.read_csv(r'/Users/loganhornbuckle/Desktop/Logan/Merged/all_years_merged_logan_mouna_darpan.csv',
                       encoding='cp1252' ,dtype='str', error_bad_lines=False)

# get dimmensions of dataframe to ensure csv imported correctly
df_logan.shape
# Out:
# (85082, 12)

# %%
df_logan
# Out:
#                       eid cite Lang  \
# 0      2-s2.0-38049161948    2  eng
# 1      2-s2.0-36749042030   17  eng
# 2      2-s2.0-84858487958    0  eng
# 3      2-s2.0-84858511527    0  eng
# 4      2-s2.0-84858503835    0  eng
# 5      2-s2.0-37349108551    3  eng
# 6      2-s2.0-37349041400    7  eng
# 7      2-s2.0-37349014523    3  eng
# 8      2-s2.0-84858512072    0  eng
# 9      2-s2.0-37349065612    6  eng
# 10     2-s2.0-37349042217    0  NaN
# 11     2-s2.0-36048947403    8  eng
# 12     2-s2.0-37349030190    1  eng
# 13     2-s2.0-37349084966    4  eng
# 14     2-s2.0-37349039010    0  NaN
# 15     2-s2.0-84858483521    0  eng
# 16     2-s2.0-37349071519    8  eng
# 17     2-s2.0-84988591378    0  eng
# 18     2-s2.0-41049089044    4  eng
# 19     2-s2.0-37349127372    2  eng
# 20     2-s2.0-40549117909    2  eng
# 21     2-s2.0-38749134080    0  eng
# 22     2-s2.0-37249048033    0  eng
# 23     2-s2.0-37249038031    0  eng
# 24     2-s2.0-37249001273    0  NaN
# ...

# %%
df_thCSC = df_logan.loc[df_logan['Text'].isin(['Theoretical Computer Science'])]
df_genCSC = df_logan.loc[df_logan['Text'].isin(['Computer Science (all)'])]
df_molBIO = df_logan.loc[df_logan['Text'].isin(['Molecular Biology'])]
df_GEN = df_logan.loc[df_logan['Text'].isin(['Genetics'])]
df_appCSC = df_logan.loc[df_logan['Text'].isin(['Computer Science Applications'])]
df_BIOcheMB = df_logan.loc[df_logan['Text'].isin(['Biochemistry, Genetics and Molecular Biology (all)'])]
df_BIOMedEng = df_logan.loc[df_logan['Text'].isin(['Biomedical Engineering'])]
df_BIOchem = df_logan.loc[df_logan['Text'].isin(['Biochemistry'])]
df_MED = df_logan.loc[df_logan['Text'].isin(['Medicine (all)'])]
df_MATH = df_logan.loc[df_logan['Text'].isin(['Applied Mathematics'])]

# %%
df_thCSC['cite'] = pd.to_numeric(df_thCSC['cite'], downcast=None)
df_genCSC['cite'] = pd.to_numeric(df_genCSC['cite'], downcast=None)
df_molBIO['cite'] = pd.to_numeric(df_molBIO['cite'], downcast=None)
df_GEN['cite'] = pd.to_numeric(df_GEN['cite'], downcast=None)
df_appCSC['cite'] = pd.to_numeric(df_appCSC['cite'], downcast=None)
df_BIOcheMB['cite'] = pd.to_numeric(df_BIOcheMB['cite'], downcast=None)
df_BIOMedEng['cite'] = pd.to_numeric(df_BIOMedEng['cite'], downcast=None)
df_BIOchem['cite'] = pd.to_numeric(df_BIOchem['cite'], downcast=None)
df_MED['cite'] = pd.to_numeric(df_MED['cite'], downcast=None)
df_MATH['cite'] = pd.to_numeric(df_MATH['cite'], downcast=None)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# ...

# %%
df_logan['cite'] = pd.to_numeric(df_logan['cite'], downcast=None)

# %%
df_thCSC
# Out:
#                       eid  cite Lang  \
# 12     2-s2.0-37349030190     1  eng
# 19     2-s2.0-37349127372     2  eng
# 25     2-s2.0-37249067061     0  NaN
# 38     2-s2.0-37249075041     0  NaN
# 41     2-s2.0-37249072490     0  NaN
# 44     2-s2.0-37249059329     0  NaN
# 45     2-s2.0-37249071408     0  NaN
# 49     2-s2.0-84857627644     0  NaN
# 52     2-s2.0-37249069367     3  eng
# 55     2-s2.0-37249092973     2  eng
# 58     2-s2.0-37249087909     3  eng
# 61     2-s2.0-37249006817     2  eng
# 64     2-s2.0-37249064221     0  eng
# 65     2-s2.0-37249025116     0  eng
# 67     2-s2.0-37249014401    11  eng
# 71     2-s2.0-37249042751     1  eng
# 74     2-s2.0-37249026752     0  eng
# 77     2-s2.0-36248961670    19  eng
# 80     2-s2.0-42149187635    35  eng
# 83     2-s2.0-42149105642    14  eng
# 86     2-s2.0-37149016806     0  NaN
# 87     2-s2.0-37149019919     0  NaN
# 91     2-s2.0-37149026778     0  NaN
# 94     2-s2.0-37149019373     0  NaN
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.distplot(df_appCSC['cite'], hist = False, kde = True,kde_kws = {'shade': True, 'linewidth': 3}, label = 'App CSC')
sns.distplot(df_GEN['cite'], hist = False, kde = True,kde_kws = {'shade': True, 'linewidth': 3}, label = 'Genetics')
sns.distplot(df_appCSC['cite'], hist = False, kde = True,kde_kws = {'shade': True, 'linewidth': 3}, label = 'App CSC')
sns.distplot(df_BIOcheMB['cite'], hist = False, kde = True,kde_kws = {'shade': True, 'linewidth': 3}, label = 'BioChem')
sns.distplot(df_MATH['cite'], hist = False, kde = True,kde_kws = {'shade': True, 'linewidth': 3}, label = 'Math')
sns.distplot(df_molBIO['cite'], hist = False, kde = True,kde_kws = {'shade': True, 'linewidth': 3}, label = 'Mol Bio')

plt.xlim(0,200)
# Out:
# (0, 200)

# %%
sns.distplot(df_MATH['cite'], hist = False, kde = True,kde_kws = {'shade': True, 'linewidth': 3}, label = 'Math')

sns.distplot(df_BIOcheMB['cite'], hist = False, kde = True,kde_kws = {'shade': True, 'linewidth': 3}, label = 'BioChem')

plt.xlim(0,200)
# Out:
# (0, 200)

# %%
 ax = sns.boxplot(x='Text', y='cite', data=df_logan)

# %%
sns.boxplot(y='Text', x='cite', data=df_BIOMedEng)
plt.xlim(0,35)
# Out:
# (0, 35)

# %%
ax = sns.boxplot(df_thCSC['cite'])
plt.xlim(0,35)
# Out:
# (0, 35)
