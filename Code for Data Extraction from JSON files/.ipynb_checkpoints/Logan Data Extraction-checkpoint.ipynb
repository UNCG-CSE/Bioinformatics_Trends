# %% [markdown]
# # Convert relevant data from JSON to CSV file
#
# The following code is for the Author-Keywords and Subject-Areas of BioInformatics Papers.
#
# NOTE: I used the following code for all 6 JSON files, changing only the file name in notebook 1 (JSON input) and notebook 12 (CSV output)

# %%
# Load json file

import json
import pandas

json_data = open(r'/Users/loganhornbuckle/Documents/Python/DataScience/raw_json_full/good/scopus2016-2017.json').read()
data = json.loads(json_data)

# %%
# check if json file properly read

print(data[0])
# Out:
# {'abstracts-retrieval-response': {'@xmlns': 'http://www.elsevier.com/xml/svapi/abstract/dtd', '@xmlns:ait': 'http://www.elsevier.com/xml/ani/ait', '@xmlns:ce': 'http://www.elsevier.com/xml/ani/common', '@xmlns:cto': 'http://www.elsevier.com/xml/cto/dtd', '@xmlns:dc': 'http://purl.org/dc/elements/1.1/', '@xmlns:prism': 'http://prismstandard.org/namespaces/basic/2.0/', '@xmlns:xocs': 'http://www.elsevier.com/xml/xocs/dtd', '@xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance', 'coredata': {'prism:url': 'http://api.elsevier.com/content/abstract/scopus_id/84992650141', 'dc:identifier': 'SCOPUS_ID:84992650141', 'eid': '2-s2.0-84992650141', 'prism:doi': '10.1007/978-3-319-46801-3_7', 'dc:title': 'An algorithm based on a directed acyclic word graph', 'prism:aggregationType': 'Book Series', 'srctype': 'k', 'citedby-count': '0', 'prism:publicationName': 'Studies in Computational Intelligence', 'dc:publisher': 'Springer Verlag service@springer.de', 'source-id': '4900152708', 'prism:issn': '1860949X', 'prism:volume': '673', 'prism:startingPage': '77', 'prism:endingPage': '81', 'prism:pageRange': '77-81', 'prism:coverDate': '2017-10-01', 'dc:creator': {'author': {'@auid': '7007161711', '@seq': '1', 'ce:initials': 'W.', 'ce:indexed-name': 'Wieczorek W.', 'ce:surname': 'Wieczorek', 'ce:given-name': 'Wojciech', 'preferred-name': {'ce:initials': 'W.', 'ce:indexed-name': 'Wieczorek W.', 'ce:surname': 'Wieczorek', 'ce:given-name': 'Wojciech'}, 'author-url': 'http://api.elsevier.com/content/author/author_id/7007161711', 'affiliation': {'@href': 'http://api.elsevier.com/content/affiliation/affiliation_id/60006225', '@id': '60006225'}}}, 'dc:description': {'abstract': {'@original': 'y', '@xml:lang': 'eng', 'publishercopyright': '© Springer International Publishing AG 2017.', 'ce:para': 'In this chapter an algorithm for the induction of a Directed Acyclic Word Graph (DAWG) is proposed. A DAWG can serve as a very efficient data structure for lexicon representation and fast string matching, and it may have a variety of applications as well. Since a DAWG is acyclic the proposed method is suited for GI problems where the target language does not necessarily have to be infinite. The results of experiments showed in the next chapter for a dataset from the domain of bioinformatics reveal that this approach may compete with the current state-of-the-art methods in heuristic DFA induction.'}}, 'intid': '84992650141', 'link': [{'@href': 'http://api.elsevier.com/content/abstract/scopus_id/84992650141', '@rel': 'self'}, {'@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=84992650141&origin=inward', '@rel': 'scopus'}, {'@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=84992650141&origin=inward', '@rel': 'scopus-citedby'}]}, 'affiliation': {'@href': 'http://api.elsevier.com/content/affiliation/affiliation_id/60006225', '@id': '60006225', 'affilname': 'Uniwersytet Slaski w Katowicach', 'affiliation-city': 'Katowice', 'affiliation-country': 'Poland'}, 'authors': {'author': {'@auid': '7007161711', '@seq': '1', 'ce:initials': 'W.', 'ce:indexed-name': 'Wieczorek W.', 'ce:surname': 'Wieczorek', 'ce:given-name': 'Wojciech', 'preferred-name': {'ce:initials': 'W.', 'ce:indexed-name': 'Wieczorek W.', 'ce:surname': 'Wieczorek', 'ce:given-name': 'Wojciech'}, 'author-url': 'http://api.elsevier.com/content/author/author_id/7007161711', 'affiliation': {'@href': 'http://api.elsevier.com/content/affiliation/affiliation_id/60006225', '@id': '60006225'}}}, 'language': {'@xml:lang': 'eng'}, 'authkeywords': None, 'idxterms': None, 'subject-areas': {'subject-area': {'@abbrev': 'COMP', '@code': '1702', '#text': 'Artificial Intelligence'}}, 'item': {'@xmlns': '', 'ait:process-info': {'ait:date-delivered': {'@day': '11', '@month': '01', '@timestamp': '2017-01-11T15:51:52.000052+00:00', '@year': '2017'}, 'ait:date-sort': {'@day': '01', '@month': '10', '@year': '2017'}, 'ait:status': {'@stage': 'S300', '@state': 'update', '@type': 'core'} ...

# %%
# append eid to eid list

eid = []

for x in range (len(data)):
    if 'abstracts-retrieval-response' in data[x].keys():
        if 'coredata' in data[x]['abstracts-retrieval-response'].keys():
            if (data[x]['abstracts-retrieval-response']['coredata']) == None:
                eid.append("NaN")
            else:
                eid.append(data[x]['abstracts-retrieval-response']['coredata']['eid'])
    else:
        eid.append("NaN")

# %%
# append author-keyword keys to keyword list

keyword = []

for x in range (len(data)):
    if 'abstracts-retrieval-response' in data[x].keys():
        if ('authkeywords' in data[x]['abstracts-retrieval-response'].keys()):
            if (data[x]['abstracts-retrieval-response']['authkeywords']) == None:
                keyword.append("NaN")
            else:
                keyword.append(data[x]['abstracts-retrieval-response']['authkeywords']['author-keyword'])
    else:
        keyword.append("NaN")

# %%
# append subject keys to list subject

subAbbrev = []
subCode = []
subText = []
                
# append subkeys of subject: @abbrev, @code, and #text to seperate lists
for x in range (len(data)):
    if 'abstracts-retrieval-response' in data[x].keys():
        if data[x]['abstracts-retrieval-response']['subject-areas'] == None:
            subAbbrev.append("NaN")
            subCode.append("NaN")
            subText.append("NaN")
        else:
            if type(data[x]['abstracts-retrieval-response']['subject-areas']['subject-area']) is list:
                for i in range(len(data[x]['abstracts-retrieval-response']['subject-areas']['subject-area'])):
                    subAbbrev.append(data[x]['abstracts-retrieval-response']['subject-areas']['subject-area'][i]['@abbrev'])
                    subCode.append(data[x]['abstracts-retrieval-response']['subject-areas']['subject-area'][i]['@code'])
                    subText.append(data[x]['abstracts-retrieval-response']['subject-areas']['subject-area'][i]['#text'])
            else:
                subAbbrev.append(data[x]['abstracts-retrieval-response']['subject-areas']['subject-area']['@abbrev'])
                subCode.append(data[x]['abstracts-retrieval-response']['subject-areas']['subject-area']['@code'])
                subText.append(data[x]['abstracts-retrieval-response']['subject-areas']['subject-area']['#text'])
    else:
        subAbbrev.append("NaN")
        subCode.append("NaN")
        subText.append("NaN")

# %%
# print length of lists to check for errors

#print("keyword length: " , len(keyword))
#print("text length: " , len(subText))
#print("abbrev length: " , len(subAbbrev))
#print("code length: " , len(subCode))
print("eid length: " , len(eid))
print(eid)
# Out:
# eid length:  7342
# ['2-s2.0-84992650141', '2-s2.0-85008506396', '2-s2.0-84997190947', '2-s2.0-85003587564', '2-s2.0-85006304239', '2-s2.0-85009348432', '2-s2.0-85006304193', '2-s2.0-84981738091', '2-s2.0-85000352209', '2-s2.0-85003554417', '2-s2.0-85007107119', '2-s2.0-85008352108', '2-s2.0-84992070728', '2-s2.0-85008425635', '2-s2.0-84996605931', '2-s2.0-85009476310', '2-s2.0-84994381596', '2-s2.0-84978933873', '2-s2.0-85006856638', '2-s2.0-84959060688', '2-s2.0-84997611190', '2-s2.0-85007385521', '2-s2.0-85008622612', '2-s2.0-84989866090', '2-s2.0-85008191019', '2-s2.0-84999666534', '2-s2.0-84939525237', '2-s2.0-84995528482', '2-s2.0-85007442832', '2-s2.0-85006988859', '2-s2.0-85007364100', '2-s2.0-85002339079', '2-s2.0-85007438937', '2-s2.0-84977617290', '2-s2.0-85006789429', '2-s2.0-85004097366', '2-s2.0-85000352063', '2-s2.0-85009107910', '2-s2.0-84997284824', '2-s2.0-84997113401', '2-s2.0-85001948854', '2-s2.0-85000428354', '2-s2.0-85006160246', '2-s2.0-85007256447', '2-s2.0-85008930395', '2-s2.0-84995750480', '2-s2.0-85009178467', '2-s2.0-84999260876', '2-s2.0-85008373480', '2-s2.0-85007071360', '2-s2.0-85004075717', '2-s2.0-85002677773', '2-s2.0-85009355033', '2-s2.0-85009469054', '2-s2.0-85007273883', '2-s2.0-85008167406', '2-s2.0-85003952957', '2-s2.0-85008599086', '2-s2.0-85008888475', '2-s2.0-85007454300', '2-s2.0-84989173764', '2-s2.0-85007553276', '2-s2.0-85008881603', '2-s2.0-85005981003', '2-s2.0-85009119440', '2-s2.0-84996555386', '2-s2.0-85009348354', '2-s2.0-84995969060', '2-s2.0-84930152454', '2-s2.0-84996508789', '2-s2.0-85000444088', '2-s2.0-85002262379', '2-s2.0-84995738136', '2-s2.0-84995688291', '2-s2.0-85008659746', '2-s2.0-84973532029', '2-s2.0-85002604759', '2-s2.0-85008245189', '2-s2.0-85003815154', '2-s2.0-85007499936', '2-s2.0-84959544891', '2-s2.0-84983541784', '2-s2.0-85006826120', '2-s2.0-84999016883', '2-s2.0-84994355447', '2-s2.0-85006372363', '2-s2.0-85006350404', '2-s2.0-84978653452', '2-s2.0-85007093220', '2-s2.0-84995972672', '2-s2.0-84993929537', '2-s2.0-85009062887', '2-s2.0-85009216493', '2-s2.0-85005959027', '2-s2.0-85002245042', '2-s2.0-85009100468', '2-s2.0-84998636603', '2-s2.0-85008440534', '2-s2.0-85008178688', '2-s2.0-85009126480', '2-s2.0-85009428618', '2-s2.0-85008177144', '2-s2.0-85002734247', '2-s2.0-84979987676', '2-s2.0-85008315214', '2-s2.0-85006058388', '2-s2.0-85006056421', '2-s2.0-85009387037', '2-s2.0-84994223718', '2-s2.0-84994052024', '2-s2.0-84993965183', '2-s2.0-84994036975', '2-s2.0-84994032133', '2-s2.0-85009348418', '2-s2.0-85009382820', '2-s2.0-85008195261', '2-s2.0-85007036242', '2-s2.0-85009437458', '2-s2.0-84971654735', '2-s2.0-85009469009', '2-s2.0-84979521151', '2-s2.0-85002595974', '2-s2.0-85007341811', '2-s2.0-84999652031', '2-s2.0-84986880022', '2-s2.0-84997785117', '2-s2.0-85002628362', '2-s2.0-85008978616', '2-s2.0-85009348547', '2-s2.0-85009372721', '2-s2.0-85009289313', '2-s2.0-85009237705', '2-s2.0-85009250104', '2-s2.0-85009168843', '2-s2.0-85009115866', '2-s2.0-85009083497', '2-s2.0-84997284008', '2-s2.0-85009164428', '2-s2.0-85008716299', '2-s2.0-85008602013', '2-s2.0-85009373418', '2-s2.0-85008661369', '2-s2.0-85009110385', '2-s2.0-85008600048', '2-s2.0-85009348931', '2-s2.0-85008465293', '2-s2.0-85007366133', '2-s2.0-85008411938', '2-s2.0-85008431808', '2-s2.0-85008354394', '2-s2.0-84988843652', '2-s2.0-85008440469', '2-s2.0-84982732897', '2-s2.0-85008655876', '2-s2.0-85009396486', '2-s2.0-85008425449', '2-s2.0-84988025218', '2-s2.0-85009347959', '2-s2.0-85008479952', '2-s2.0-84994351094', '2-s2.0-84994545296', '2-s2.0-85008220543', '2-s2.0-85008413195', '2-s2.0-85008354482', '2-s2.0-85008319419', '2-s2.0-85008517585', '2-s2.0-85008411896', '2-s2.0-84992169530', '2-s2.0-85008689564', '2-s2.0-85006931188', '2-s2.0-85008155370', '2-s2.0-85008323993', '2-s2.0-85008145219', '2-s2.0-85008233910', '2-s2.0-85007559147', '2-s2.0-85008932613', '2-s2.0-85008194288', '2-s2.0-84996968391', '2-s2.0-84989261653', '2-s2.0-84988642789', '2-s2.0-84988596721', '2-s2.0-850091543 ...

# %%
# crate dataFrame
df = pandas.DataFrame()

#Create column for Author Keyword
df["Author Keyword"] = keyword
df[:5]
# Out:
#                                       Author Keyword
# 0  [Computational biology, Neurodegenerative dise...
# 1  [Biodiversity, Biological resource centre, Cya...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
# Create column for eid


for n in range (len(eid)):
    df["eID"] = eid[n]

for n in range (len(eid)):
    df["eID"][n] = eid[n]

df[:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e629ed090c93> in <module>()
#       2
#       3
# ----> 4 for n in range (len(eid)):
#       5     df["eID"] = eid[n]
#       6
#
# NameError: name 'eid' is not defined

# %%
# Create column for Subject Area: Abbreviation


for n in range (len(subAbbrev)):
    df["Abbreviation"] = subAbbrev[n]

for n in range (len(subAbbrev)):
    df["Abbreviation"][n] = subAbbrev[n]

df[:5]
# Out:
#                                       Author Keyword Abbreviation
# 0  [Computational biology, Neurodegenerative dise...         BIOC
# 1  [Biodiversity, Biological resource centre, Cya...         BIOC
# 2                                                NaN         BIOC
# 3                                                NaN         ENGI
# 4                                                NaN         ENGI

# %%
# Create column for Subject Area: Code

for n in range(len(subCode)):
    df["Code"] = subCode[n]

for n in range(len(subCode)):
    df["Code"][n] = subCode[n]

df[:5]
# Out:
#                                       Author Keyword Abbreviation  Code
# 0  [Computational biology, Neurodegenerative dise...         BIOC  1303
# 1  [Biodiversity, Biological resource centre, Cya...         BIOC  1311
# 2                                                NaN         BIOC  1311
# 3                                                NaN         ENGI  2200
# 4                                                NaN         ENGI  2200

# %%
# Create column for Subject Area: Text

for n in range(len(subText)):
    df["Text"] = subText[n]
    
for n in range(len(subText)):
    df["Text"][n] = subText[n]

df[:5]
# Out:
#                                       Author Keyword Abbreviation  Code  \
# 0  [Computational biology, Neurodegenerative dise...         BIOC  1303
# 1  [Biodiversity, Biological resource centre, Cya...         BIOC  1311
# 2                                                NaN         BIOC  1311
# 3                                                NaN         ENGI  2200
# 4                                                NaN         ENGI  2200
#
#                 Text
# 0       Biochemistry
# 1           Genetics
# 2           Genetics
# 3  Engineering (all)
# 4  Engineering (all)

# %%
# preview data frame

df[:100]
# Out:
#                                        Author Keyword Abbreviation  Code  \
# 0   [Computational biology, Neurodegenerative dise...         BIOC  1303
# 1   [Biodiversity, Biological resource centre, Cya...         BIOC  1311
# 2                                                 NaN         BIOC  1311
# 3                                                 NaN         ENGI  2200
# 4                                                 NaN         ENGI  2200
# 5   [Bioinformatics tool, Comparative genomic hybr...         ENGI  2200
# 6   [Ab initio prediction, Molecular dynamics simu...         BIOC  1311
# 7   [Bioinformatics, Flagellar motility, Genome sc...         BIOC  1311
# 8                                                 NaN         BIOC  1311
# 9   [ECG signal processing, Heart monitoring, Mobi...         ENGI  2200
# 10                                                NaN         BIOC  1300
# 11     [Effector component, Lectin pathway, Promoter]         COMP  1700
# 12  [3-D modeling, Bioinformatics, Capsule endosco...         MATH  2614
# 13  [Bioinformatics, Latent semantic indexing, Mol...         BIOC  1311
# 14                                                NaN         BIOC  1303
# 15                                                NaN         BIOC  1304
# 16  [Discretization, Gene expression data, Reducts...         BIOC  1312
# 17                                                NaN         COMP  1700
# 18                                                NaN         BIOC  1300
# 19                                                NaN         MATH  2614
# 20                     [Astrocytoma, Proteomics, Rat]         BIOC  1312
# 21  [Critical residue, Gentisate 1,2-dioxygenase, ...         BIOC  1311
# 22                                                NaN         AGRI  1100
# 23                                                NaN         AGRI  1101
# 24                                                NaN         ENGI  2200
# 25                                                NaN         MATH  2614
# 26                                                NaN         COMP  1700
# 27                                                NaN         AGRI  1100
# 28                                                NaN         BIOC  1300
# 29                                                NaN         MEDI  2700
# ..                                                ...          ...   ...
# 70                                                NaN         BIOC  1300
# 71  [Adaptive control, Artificial immune systems, ...         MATH  2614
# 72                                                NaN         COMP  1700
# 73                                                NaN         BIOC  1300
# 74                                                NaN         MATH  2614
# 75                                                NaN         COMP  1700
# 76                                                NaN         BIOC  1300
# 77  [γ-Turn types, Support vector machines (SVMs),...         MATH  2614
# 78                                                NaN         BIOC  1300
# 79                                                NaN         COMP  1700
# 80                                                NaN         MATH  2614
# 81                                                NaN         COMP  1700
# 82                                                NaN         BIOC  1300
# 83                                                NaN         MATH  2614
# 84                                                NaN         COMP  1700
# 85                                                NaN         BIOC  1300
# 86                                                NaN         MATH  2614
# 87                                                NaN         MATH  2614
# 88                                                NaN         COMP  1700
# 89                                                NaN         COMP  1700
# 90                                                NaN         BIOC  1300
# 91                                                NaN         MATH  2614
# 92                                                NaN         COMP  1700
# 93                                                NaN         BIOC  1300
# 94                                                NaN         MATH  2614
# 95                                                NaN         COMP  1700
# 96                                                NaN         BIOC  1300
# 97                                                NaN         MATH  2614
# 98                                                NaN         BIOC  1300
# 99                                                NaN         COMP  1700
#
#                                                  Text
# 0                                        Biochemistry
# 1                                            Genetics
# 2                                            Genetics
# 3                                   Engineering (all)
# 4                                   Engineering (all)
# 5                                   Engineering (all)
# 6                                            Genetics
# 7                                            Genetics
# 8                                            Genetics
# 9                                   Engineering (all)
# 10  Biochemistry, Genetics and Molecular Biology (...
# 11                             Computer Science (all)
# 12                       Theoretical Computer Science
# 13                                           Genetics
# 14                                       Biochemistry
# 15                                         Biophysics
# 16                                  Molecular Biology
# 17                             Computer Science (all)
# 18  Biochemistry, Genetics and Molecular Biology (...
# 19                       Theoretical Computer Science
# 20                                  Molecular Biology
# 21                                           Genetics
# 22         Agricultural and Biological Sciences (all)
# 23  Agricultural and Biological Sciences (miscella...
# 24                                  Engineering (all)
# 25                       Theoretical Computer Science
# 26                             Computer Science (all)
# 27         Agricultural and Biological Sciences (all)
# 28  Biochemistry, Genetics and Molecular Biology (...
# 29                                     Medicine (all)
# ..                                                ...
# 70  Biochemistry, Genetics and Molecular Biology (...
# 71                       Theoretical Computer Science
# 72                             Computer Science (all)
# 73  Biochemistry, Genetics and Molecular Biology (...
# 74                       Theoretical Computer Science
# 75                             Computer Science (all)
# 76  Biochemistry, Genetics and Molecular Biology (...
# 77                       Theoretical Computer Science
# 78  Biochemistry, Genetics and Molecular Biology (...
# 79                             Computer Science (all)
# 80                       Theoretical Computer Science
# 81                             Computer Science (all)
# 82  Biochemistry, Genetics and Molecular Biology (...
# 83                       Theoretical Computer Science
# 84                             Computer Science (all)
# 85  Biochemistry, Genetics and Molecular Biology (...
# 86                       Theoretical Computer Science
# 87                       Theoretical Computer Science
# 88                             Computer Science (all)
# 89                             Computer Science (all)
# 90  Biochemistry, Genetics and Molecular Biology (...
# 91                       Theoretical Computer Science
# 92                             Computer Science (all)
# 93  Biochemistry, Genetics and Molecular Biology (...
# 94                       Theoretical Computer Science
# 95                             Computer Science (all)
# 96  Biochemistry, Genetics and Molecular Biology (...
# 97                       Theoretical Computer Science
# 98  Biochemistry, Genetics and Molecular Biology (...
# 99                             Computer Science (all)
#
# [100 rows x 4 columns]

# %%
# create csv file from data frame

df.to_csv('gr3_86_07.csv')
