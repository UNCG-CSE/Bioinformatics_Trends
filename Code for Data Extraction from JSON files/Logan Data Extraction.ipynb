# %% [markdown]
# # Convert relevant data from JSON to CSV file
#
# The following code is for the Author-Keywords and Subject-Areas of BioInformatics Papers.
#
# NOTE: I used the following code for all 6 JSON files, changing only the file name in notebook 1 (JSON input) and notebook 12 (CSV output)

# %%
# Load json file

import json
import pandas

json_data = open(r'/Users/loganhornbuckle/Documents/Python/DataScience/raw_json_full/good/scopus2016-2017.json').read()
data=json.loads(json_data)

# %%
# check if json file properly read

print(len(data))
# Out:
# 7342

# %%
# append author-keyword keys to keyword list

keyword = []

for x in range (len(data)):
    if 'abstracts-retrieval-response' in data[x].keys():
        if ('authkeywords' in data[x]['abstracts-retrieval-response'].keys()):
            if (data[x]['abstracts-retrieval-response']['authkeywords']) == None:
                keyword.append("NaN")
            else:
                keyword.append(data[x]['abstracts-retrieval-response']['authkeywords']['author-keyword'])

# %%
# append subject keys to list subject

subAbbrev = []
subCode = []
subText = []
                
# append subkeys of subject: @abbrev, @code, and #text to seperate lists
for x in range (len(data)):
    if 'abstracts-retrieval-response' in data[x].keys():
        if data[x]['abstracts-retrieval-response']['subject-areas'] == None:
            subAbbrev.append("NaN")
            subCode.append("NaN")
            subText.append("NaN")
        else:
            if type(data[x]['abstracts-retrieval-response']['subject-areas']['subject-area']) is list:
                for i in range(len(data[x]['abstracts-retrieval-response']['subject-areas']['subject-area'])):
                    subAbbrev.append(data[x]['abstracts-retrieval-response']['subject-areas']['subject-area'][i]['@abbrev'])
                    subCode.append(data[x]['abstracts-retrieval-response']['subject-areas']['subject-area'][i]['@code'])
                    subText.append(data[x]['abstracts-retrieval-response']['subject-areas']['subject-area'][i]['#text'])
            else:
                subAbbrev.append(data[x]['abstracts-retrieval-response']['subject-areas']['subject-area']['@abbrev'])
                subCode.append(data[x]['abstracts-retrieval-response']['subject-areas']['subject-area']['@code'])
                subText.append(data[x]['abstracts-retrieval-response']['subject-areas']['subject-area']['#text'])

# %%
# print length of lists to check for errors

print("keyword length: " , len(keyword))
print("text length: " , len(subText))
print("abbrev length: " , len(subAbbrev))
print("code length: " , len(subCode))
# Out:
# keyword length:  7339
# text length:  20085
# abbrev length:  20085
# code length:  20085

# %%
# crate dataFrame
df = pandas.DataFrame()

#Create column for Author Keyword
df["Author Keyword"] = keyword
df[:5]
# Out:
#                                       Author Keyword
# 0                                                NaN
# 1  [Bioinformatics tool, Gene variant, Single Nuc...
# 2  [Bioinformatics, CRYAB, HSPB5, Molecular dynam...
# 3                                                NaN
# 4  [Benders decomposition, Bioinformatics, Combin...

# %%
# Create column for Subject Area: Abbreviation


for n in range (len(subAbbrev)):
    df["Abbreviation"] = subAbbrev[n]

for n in range (len(subAbbrev)):
    df["Abbreviation"][n] = subAbbrev[n]

df[:5]
# Out:
#                                       Author Keyword Abbreviation
# 0                                                NaN         COMP
# 1  [Bioinformatics tool, Gene variant, Single Nuc...         BIOC
# 2  [Bioinformatics, CRYAB, HSPB5, Molecular dynam...         MEDI
# 3                                                NaN         MEDI
# 4  [Benders decomposition, Bioinformatics, Combin...         BIOC

# %%
# Create column for Subject Area: Code

for n in range(len(subCode)):
    df["Code"] = subCode[n]

for n in range(len(subCode)):
    df["Code"][n] = subCode[n]

df[:5]
# Out:
#                                       Author Keyword Abbreviation  Code
# 0                                                NaN         COMP  1702
# 1  [Bioinformatics tool, Gene variant, Single Nuc...         BIOC  1311
# 2  [Bioinformatics, CRYAB, HSPB5, Molecular dynam...         MEDI  2716
# 3                                                NaN         MEDI  2734
# 4  [Benders decomposition, Bioinformatics, Combin...         BIOC  1313

# %%
# Create column for Subject Area: Text

for n in range(len(subText)):
    df["Text"] = subText[n]
    
for n in range(len(subText)):
    df["Text"][n] = subText[n]

df[:5]
# Out:
#                                       Author Keyword Abbreviation  Code  \
# 0                                                NaN         COMP  1702
# 1  [Bioinformatics tool, Gene variant, Single Nuc...         BIOC  1311
# 2  [Bioinformatics, CRYAB, HSPB5, Molecular dynam...         MEDI  2716
# 3                                                NaN         MEDI  2734
# 4  [Benders decomposition, Bioinformatics, Combin...         BIOC  1313
#
#                               Text
# 0          Artificial Intelligence
# 1                         Genetics
# 2              Genetics (clinical)
# 3  Pathology and Forensic Medicine
# 4               Molecular Medicine

# %%
# preview data frame

df[:100]
# Out:
#                                        Author Keyword Abbreviation  Code  \
# 0                                                 NaN         COMP  1702
# 1   [Bioinformatics tool, Gene variant, Single Nuc...         BIOC  1311
# 2   [Bioinformatics, CRYAB, HSPB5, Molecular dynam...         MEDI  2716
# 3                                                 NaN         MEDI  2734
# 4   [Benders decomposition, Bioinformatics, Combin...         BIOC  1313
# 5   [Diptericin, Drosophila melanogaster, Imd path...         MEDI  2737
# 6   [Bacillus, Cocoa fermentation, DegU regulator,...         ENGI  2207
# 7   [Bioinformatics, Computational proteomics, Mas...         ENGI  2210
# 8   [Collusion-resistant fingerprinting, P2P conte...         MATH  2604
# 9   [DNA-binding protein prediction, Feature repre...         MATH  2611
# 10                                                NaN         DECI  1803
# 11  [Classification, L1-regularized logistic regre...         DECI  1802
# 12                                                NaN         IMMU  2403
# 13  [Active site, Comparative model, Denitrificati...         BIOC  1309
# 14  [Ca2 +-binding protein, Calmodulin, ELISA, Imm...         IMMU  2404
# 15  [Host-toxicity, In vitro antibacterial study, ...         AGRI  1106
# 16                                                NaN         ENGI  2207
# 17  [Avidin, Biosensors, Electrochemical impedance...         MATH  2614
# 18  [Feature extraction, L2,1-norm constraint, RNA...         COMP  1712
# 19  [biological realism, epistemology computer sim...         COMP  1706
# 20  [Adaptive user interaction, Biomedical ontolog...         DECI  1802
# 21  [Dominant markers, GelJ, Interoperability, Phy...         COMP  1702
# 22   [Esterase, Halophilic, Janibacter, Thermophilic]         ENGI  2200
# 23  [Scientific workflows, Software product line, ...         COMP  1706
# 24  [Bioinformatics prediction, Common or rare var...         COMP  1702
# 25  [Azonia aromatic heterocycles, Cell staining, ...         ENGI  2207
# 26  [Agonist, Human estrogen receptor alpha, Molec...         MATH  2614
# 27  [Bioinformatics, Neurohormone, Neuropeptide, T...         COMP  1712
# 28  [Band-like model, Charge transport, DNA, Hoppi...         COMP  1706
# 29  [Finite element method, Fluid, Interface condi...         DECI  1802
# ..                                                ...          ...   ...
# 70  [Bioinformatics, Expression, MicroRNA, qRT-PCR...         COMP  1705
# 71  [Acute lymphoblastic leukemia, Bioinformatics,...         MEDI  2700
# 72  [30S ribosomal protein S2, Chlamydophila pneum...         BIOC  1311
# 73  [Bioinformatics analysis, Chemosensory protein...         CENG  1500
# 74  [Biodeterioration, Buddhist statues, High-thro...         CENG  1508
# 75  [Bioinformatics, Energy efficiency, FiPS proje...         MATH  2614
# 76  [Bioinformatics, Eggplant, Food allergen, IgE ...         COMP  1700
# 77  [Bee colony optimization, Honey bees foraging,...         MATH  2612
# 78  [Artificial bee colony, Biological-inspired op...         MATH  2611
# 79  [bioinformatics, epithelial tubule formation, ...         MATH  2604
# 80  [Big data management, Bioinformatics, Data-int...         BIOC  1310
# 81  [3D printing, Arduino, Environmental control, ...         MATE  2504
# 82  [Elastic differential cross section, Lippmann–...         CHEM  1600
# 83  [Fused quartz, Local strength, Powder particle...         MATE  2502
# 84  [Bio-inspired computing, Cell division, Membra...         PHYS  3104
# 85  [Biological systems, Chaos theory, Evolution, ...         MATE  2505
# 86  [Cluster containment problem, Galled networks,...         ENGI  2208
# 87  [Business intelligence systems, Clinical admin...         MATH  2611
# 88  [Compressed sensing (CS), joint sparsity, mult...         MATH  2604
# 89  [Cluster, Irregular application, Parallel prog...         COMP  1712
# 90                                                NaN         COMP  1711
# 91  [Hypervirulence, RACK1 (Receptor for Activated...         COMP  1707
# 92  [autophagy, cardiac aging, Drosophila, FOXO, p...         ENGI  2208
# 93  [Health, Inflammation, Rhesus macaque, Social ...         ENGI  2207
# 94  [Functional characterization, Panax notoginsen...         MATH  2614
# 95  [Aortopathy, Atypical phenotype, Collagen type...         COMP  1712
# 96  [MicroRNA, miR-217, miR-8159, Regulation, Sign...         COMP  1706
# 97  [cell models, drug-induced liver injury, High-...         DECI  1802
# 98  [Beauveria bassiana, Blastospores, Cell surfac...         COMP  1702
# 99  [KPNA3, MicroRNA, Nuclear factor-κB, Osteoarth...         COMP  1712
#
#                                           Text
# 0                      Artificial Intelligence
# 1                                     Genetics
# 2                          Genetics (clinical)
# 3              Pathology and Forensic Medicine
# 4                           Molecular Medicine
# 5                         Physiology (medical)
# 6              Control and Systems Engineering
# 7                       Mechanical Engineering
# 8                          Applied Mathematics
# 9                      Modeling and Simulation
# 10  Management Science and Operations Research
# 11          Information Systems and Management
# 12                                  Immunology
# 13                       Developmental Biology
# 14                                Microbiology
# 15                                Food Science
# 16             Control and Systems Engineering
# 17                Theoretical Computer Science
# 18                                    Software
# 19               Computer Science Applications
# 20          Information Systems and Management
# 21                     Artificial Intelligence
# 22                           Engineering (all)
# 23               Computer Science Applications
# 24                     Artificial Intelligence
# 25             Control and Systems Engineering
# 26                Theoretical Computer Science
# 27                                    Software
# 28               Computer Science Applications
# 29          Information Systems and Management
# ..                                         ...
# 70        Computer Networks and Communications
# 71                              Medicine (all)
# 72                                    Genetics
# 73                  Chemical Engineering (all)
# 74            Process Chemistry and Technology
# 75                Theoretical Computer Science
# 76                      Computer Science (all)
# 77                          Numerical Analysis
# 78                     Modeling and Simulation
# 79                         Applied Mathematics
# 80                               Endocrinology
# 81  Electronic, Optical and Magnetic Materials
# 82                             Chemistry (all)
# 83                                Biomaterials
# 84                    Condensed Matter Physics
# 85                         Materials Chemistry
# 86       Electrical and Electronic Engineering
# 87                     Modeling and Simulation
# 88                         Applied Mathematics
# 89                                    Software
# 90                           Signal Processing
# 91     Computer Vision and Pattern Recognition
# 92       Electrical and Electronic Engineering
# 93             Control and Systems Engineering
# 94                Theoretical Computer Science
# 95                                    Software
# 96               Computer Science Applications
# 97          Information Systems and Management
# 98                     Artificial Intelligence
# 99                                    Software
#
# [100 rows x 4 columns]

# %%
# create csv file from data frame

df.to_csv('gr3_16_17.csv')
